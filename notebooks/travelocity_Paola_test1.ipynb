# %%
# Dependencies
import os
import requests
import pandas as pd
import ssl
from bs4 import BeautifulSoup as bs
import urllib.request, urllib.parse, urllib.error
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

# %%
url = 'https://www.travelocity.ca/Flights-Search?flight-type=on&starDate=01%2F04%2F2019&endDate=30%2F04%2F2019&_xpid=11905%7C1&mode=search&trip=roundtrip&leg1=from%3AToronto%2C+ON%2C+Canada+%28YYZ-Pearson+Intl.%29%2Cto%3AHonolulu%2C+HI%2C+United+States+%28HNL-Daniel+K.+Inouye+Intl.%29%2Cdeparture%3A01%2F04%2F2019TANYT&leg2=from%3AHonolulu%2C+HI%2C+United+States+%28HNL-Daniel+K.+Inouye+Intl.%29%2Cto%3AToronto%2C+ON%2C+Canada+%28YYZ-Pearson+Intl.%29%2Cdeparture%3A30%2F04%2F2019TANYT&passengers=children%3A0%2Cadults%3A1%2Cseniors%3A0%2Cinfantinlap%3AY'

# %%
html = urllib.request.urlopen(url, context=ctx).read()

# %%
soup = bs(html, 'html.parser')

# %%
print(soup.prettify("utf-8"))
# Out:
# b'<!DOCTYPE html>\n<html class="no-js" data-language="en_CA" data-version="v2.203.0.654d97531317089b8d70d5a30b5b19c20c63415a" dir="ltr" lang="en">\n <head>\n  <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>\n  <meta charset="utf-8">\n   <link href="//a.intentmedia.net" rel="dns-prefetch"/>\n   <link href="//images.trvl-media.com" rel="dns-prefetch"/>\n   <link href="//a.travel-assets.com/" rel="dns-prefetch"/>\n   <link href="//b.travel-assets.com/" rel="dns-prefetch"/>\n   <link href="//c.travel-assets.com/" rel="dns-prefetch"/>\n   <title>\n    YYZ to HNL Flights | Travelocity\n   </title>\n   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>\n   <meta content="false" name="oip.set"/>\n   <meta content="false" name="oip.yes"/>\n   <meta content="false" name="oip.no"/>\n   <link href="/favicon.ico" rel="shortcut icon" sizes="16x16 32x32" type="image/x-icon"/>\n   <link href="/favicon.ico" rel="icon" sizes="16x16 32x32" type="image/x-icon"/>\n   <script src="//b.travel-assets.com/uitoolkit/2-203/654d97531317089b8d70d5a30b5b19c20c63415a/core/js/uitk-lib-bundle-min.js">\n   </script>\n   <!--[if IE 8]>\n    <script src="//b.travel-assets.com/uitoolkit/2-203/654d97531317089b8d70d5a30b5b19c20c63415a/core/js/uitk-ie8-bundle-min.js"></script>\n\n  <![endif]-->\n   <link href="//a.travel-assets.com/uitoolkit/2-203/654d97531317089b8d70d5a30b5b19c20c63415a/core/minifiedCss/brands/travelocity-responsive.css" rel="stylesheet" type="text/css"/>\n   <!--[if IE 8]>\n    <link rel=\'stylesheet\' type=\'text/css\' href=\'//a.travel-assets.com/uitoolkit/2-203/654d97531317089b8d70d5a30b5b19c20c63415a/core/minifiedCss/brands/travelocity-ie8.css\'/>\n<![endif]-->\n   <script async="" defer="" src="//b.travel-assets.com/uitoolkit/2-203/654d97531317089b8d70d5a30b5b19c20c63415a/core/js/uitk-slim-jstemplate-bundle-min.js">\n   </script>\n   <script async="" defer="" src="//a.travel-assets.com/uitoolkit/2-203/654d97531317089b8d70d5a30b5b19c20c63415a/core/js/uitk-core-bundle-min.js">\n   </script>\n   <script async="" defer="" src="https://www.expedia.com/i18n/80004/en_CA/dateTimeFormats.js?module=exp_datetimeformats&amp;">\n   </script>\n   <script type="text/javascript">\n    var collectedErrors = [];\n    (function() {\n        var previousOnError = window.onerror;\n        window.onerror = function(message, source, line, column, error) {\n            if (collectedErrors) {\n                error = error || new Error(message);\n                console.info("Collecting unhandled error \\"" + error + "\\"");\n                collectedErrors.push(error);\n            }\n            if (previousOnError) {\n                return previousOnError.apply(window, arguments);\n            }\n        };\n    })();\n\n    window.dctk = window.dctk || {};\n\n    (function( window, logging, undefined ) {\n        logging.pageStartTime = new Date().getTime();\n        logging.pageName = "page.Flight-Search-Roundtrip.Out";\n        logging.guid = "0ac99dce-5fd3-4c80-acaa-02a20424c5c7";\n        logging.data = "alternativePageName\\u003dN/A|responsive\\u003dtrue|uitk_v2\\u003dtrue|";\n    })( window, window.dctk.logging = window.dctk.logging || {} );\n   </script>\n   <script async="" defer="" src="//b.travel-assets.com/datacapture/2/js/client-logging-bundle-min.js">\n   </script>\n   <script>\n    if (!window.DCTKBootstrapIsLoaded) {\n        /* Minimal DCTK interface before it\'s fully loaded */\n        var dctk = window.dctk || {};\n        if (!dctk.enabled) {\n            dctk.enabled = true;\n            dctk._createOnQueueStrategy = function () {\n                var strategy = function (callback) { strategy._queue.push(callback); };\n                strategy._queue = [];\n                return strategy;\n            };\n            dctk.onReady = dctk._createOnQueueStrategy();\n        }\n        dctk._requestId =  "5bd8c999-ddfd-44ee-8a20-507ad133b1af" ;\n        dctk._siteId =  "80004" ;\n        \n        /**\n * In ...

# %%
results_1 = soup.find_all('div', class_="site-content-wrap")
results_1
# Out:
# [<div class="site-content-wrap site-content click-handler-range cols-row cf pi-progress-show uitk-grid uitk-drawer-wrapper all-grid-fallback-alt desktop-filter-drawer-disabled" data-drawer-disable-at="1024" id="flightSearchResultDiv" role="region">
#  <aside class="uitk-col all-x-gutter-12 uitk-drawer drawer-pos-left is-closed" data-control="drawer" id="aCol">
#  <div class="send-searches-notification-container hidden" id="sendSearchesNotificationContainer"></div>
#  <div data-test-id="fsr-sort-filter-drawer" id="sort-filter-drawer">
#  <div class="drawer-header">
#  <div class="sort-filter-drawer-title-container">
#  <div class="uitk-grid all-grid-fallback-alt all-col-1-2">
#  <button aria-label="cancel and close drawer" class="btn-primary btn-text close-filter-button filter-close" data-click-handler="omnitureClickHandler" data-control="drawer-close" data-omniture-rfrr="FLT.SR.SortFilter.Closed" id="closeDrawer" type="button"><span class="btn-label"></span></button>
#  <div class="uitk-col all-col-fill">
#  <h2 class="sort-filter-drawer-header-title no-outline" tabindex="-1">
#                          Sort &amp; Filter
#                      </h2>
#  </div>
#  <div class="uitk-col all-col-shrink">
#  <button aria-label="Clear selections" class="btn-primary btn-text sort-filter-clear-button" data-click-handler="omnitureClickHandler" data-omniture-rfrr="FLT.SR.SortFilter.Clear" disabled="" type="button"><span class="btn-label">Clear</span></button>
#  </div>
#  </div>
#  </div>
#  <div class="sort-filter-done-container">
#  <button aria-label="Close Drawer" class="btn-secondary btn-sub-action sort-filter-done-button" data-click-handler="omnitureClickHandler" data-control="drawer-close" data-omniture-rfrr="FLT.SR.SortFilter.Closed" type="button"><span class="btn-label">Close</span></button>
#  </div>
#  </div>
#  <div class="sort-filter-content">
#  <div class="input-container">
#  <div class="" id="sortBar">
#  <label class="select icon icon-toggle180 filter-label" for="sortDropdown">
#  <span class="label">Sort by</span>
#  <select id="sortDropdown"><option data-interstitial-message="Sorting by price..." data-omniture-rfrr="FLT.SR.Sort.Price.Ascending" data-opt-group="price" data-opt-id="sort-price-asc" value="price:asc">Price (Lowest)</option><option data-interstitial-message="Sorting by price..." data-omniture-rfrr="FLT.SR.Sort.Price.Descending" data-opt-group="price" data-opt-id="sort-price-desc" value="price:desc">Price (Highest)</option><option data-interstitial-message="Sorting by duration..." data-omniture-rfrr="FLT.SR.Sort.Duration.Ascending" data-opt-group="duration" data-opt-id="sort-duration-asc" value="duration:asc">Duration (Shortest)</option><option data-interstitial-message="Sorting by duration..." data-omniture-rfrr="FLT.SR.Sort.Duration.Descending" data-opt-group="duration" data-opt-id="sort-duration-desc" value="duration:desc">Duration (Longest)</option><option data-interstitial-message="Sorting by time..." data-omniture-rfrr="FLT.SR.Sort.Departure.Ascending" data-opt-id="sort-departuretime-desc" value="departuretime:asc">Departure (Earliest)</option><option data-interstitial-message="Sorting by time..." data-omniture-rfrr="FLT.SR.Sort.Departure.Descending" data-opt-id="sort-departuretime-asc" value="departuretime:desc">Departure (Latest)</option><option data-interstitial-message="Sorting by time..." data-omniture-rfrr="FLT.SR.Sort.Arrival.Ascending" data-opt-id="sort-arrivaltime-asc" value="arrivaltime:asc">Arrival (Earliest)</option><option data-interstitial-message="Sorting by time..." data-omniture-rfrr="FLT.SR.Sort.Arrival.Descending" data-opt-id="sort-arrivaltime-desc" value="arrivaltime:desc">Arrival (Latest)</option></select>
#  </label>
#  </div>
#  </div>
#  <div class="filter-separator "></div>
#  <div class="input-container pattern-filters">
#  <div class="filters-container-drawer" id="filter-container">
#  <div class="disable-overlay"></div>
#  <fieldset class="filter-set " id="">
#  <div class="uitk-grid all-grid-fallback-alt category-grid">
#  <div class="uitk-col all-col-fill">
#  <legend class="section-header-sub">
#  <span> Stops</span>
#  </legend>
#  </div>
#  <div class="uitk-col all-col-shrink">
#  <div aria-hidden="true" class="section-header-sub from-text">From:</div>
#  </div>
#  <label class="check filter-option">
#  <div class="uitk-grid all-grid-fallback-alt">
#  <div class="uitk-col all-col-fill">
#  <input type="checkbox"/>
#  <span aria-hidden="true" class="inline-label">
#                      1 Stop <span class="count">(7)</span>
#  </span>
#  </div>
#  <div class="uitk-col all-col-shrink">
#  <div aria-hidden="true" class="justify-right item-price">
#                      C$565
#                      </div>
#  </div>
#  </div>
#  </label>
#  <label class="check filter-option">
#  <div class="uitk-grid all-grid-fallback-alt">
#  <div class="uitk-col all-col-fill">
#  <input type="checkbox"/>
#  <span aria-hidden="true" class="inline-label">
#                      2+ Stops <span class="count">(13)</span>
#  </span>
#  </div>
#  <div class="uitk-col all-col-shrink">
#  <div aria-hidden="true" class="justify-right item-price">
#                      C$704
#                      </div>
#  </div>
#  </div>
#  </label>
#  </div>
#  </fieldset>
#  <fieldset class="filter-set " id="">
#  <div class="uitk-grid all-grid-fallback-alt category-grid">
#  <div class="uitk-col all-col-fill">
#  <legend class="section-header-sub">
#  <span> Airlines included</span>
#  </legend>
#  </div>
#  <div class="uitk-col all-col-shrink">
#  <div aria-hidden="true" class="section-header-sub from-text">From:</div>
#  </div>
#  <label class="check filter-option">
#  <div class="uitk-grid all-grid-fallback-alt">
#  <div class="uitk-col all-col-fill">
#  <input type="checkbox"/>
#  <span aria-hidden="true" class="inline-label">
#                                  American Airlines
#   <span class="count">(10)</span>
#  </span>
#  </div>
#  <div class="uitk-col all-col-shrink">
#  <div aria-hidden="true" class="justify-right item-price">
#                      C$704
#                      </div>
#  </div>
#  </div>
#  </label>
#  <label class="check filter-option">
#  <div class="uitk-grid all-grid-fallback-alt">
#  <div class="uitk-col all-col-fill">
#  <input type="checkbox"/>
#  <span aria-hidden="true" class="inline-label">
#                                  Delta
#   <span class="count">(5)</span>
#  </span>
#  </div>
#  <div class="uitk-col all-col-shrink">
#  <div aria-hidden="true" class="justify-right item-price">
#                      C$575
#                      </div>
#  </div>
#  </div>
#  </label>
#  <label class="check filter-option">
#  <div class="uitk-grid all-grid-fallback-alt">
#  <div class="uitk-col all-col-fill">
#  <input type="checkbox"/>
#  <span aria-hidden="true" class="inline-label">
#                                  WestJet
#   <span class="count">(3)</span>
#  </span>
#  </div>
#  <div class="uitk-col all-col-shrink">
#  <div aria-hidden="true" class="justify-right item-price">
#                      C$726
#                      </div>
#  </div>
#  </div>
#  </label>
#  <label class="check filter-option">
#  <div class="uitk-grid all-grid-fallback-alt">
#  <div class="uitk-col all-col-fill">
#  <input type="checkbox"/>
#  <span aria-hidden="true" class="inline-label">
#                                  United
#   <span class="count">(2)</span>
#  </span>
#  </div>
#  <div class="uitk-col all-col-shrink">
#  <div aria-hidden="true" class="justify-right item-price">
#                      C$565
#                      </div>
#  </div>
#  </div>
#  </label>
#  </div>
#  </fieldset>
#  <fieldset class="filter-set hide" id="departure-time-filters-outbound">
#  <div class="uitk-grid all-grid-fallback-alt category-grid">
#  <div class="uitk-col all-col-fill">
#  <legend class="section-header-sub">
#  <span> Departure time - Toronto</span>
#  </legend>
#  </div>
#  <div class="uitk-col all-col-shrink">
#  </div>
#  <label class="check filter-option">
#  <div class="uitk-grid all-grid-fallback-alt">
#  <div class="uitk-col all-col-fill">
#  <input type="checkbox"/>
#  <span aria-hidden="true" class="inline-label">
#                                      Morning (5:00am - 11:59am)
#
#                  </span>
#  </div>
#  <div class="uitk-col all-col-shrink">
#  </div>
#  </div>
#  </label>
#  <label class="check filter-option">
#  <div class="uitk-grid all-grid-fallback-alt">
#  <div class="uitk-col all-col-fill">
#  <input type="checkbox"/>
#  <span aria-hidden="true" class="inline-label">
#                                      Afternoon (12:00pm - 5:59pm)
#
#                  </span>
#  </div>
#  <div class="uitk-col all-col-shrink">
#  </div>
#  </div>
#  </label>
#  <label class="check filter-option">
#  <div class="uitk-grid all-grid-fallback-alt">
#  <div class="uitk-col all-col-fill">
#  <input type="checkbox"/>
#  <span aria-hidden="true" class="inline-label">
#                                      Evening (6:00pm - 11:59pm)
#
#                  </span>
#  </div>
#  <div class="uitk-col all-col-shrink">
#  </div>
#  </div>
#  </label>
#  </div>
#  </fieldset>
#  <fieldset class="filter-set hide" id="arrival-time-filters-outbound">
#  <div class="uitk-grid all-grid-fallback-alt category-grid">
#  <div class="uitk-col all-col-fill">
#  <legend class="section-header-sub">
#  <span> Arrival time - Honolulu</span>
#  </legend>
#  </div>
#  <div class="uitk-col all-col-shrink">
#  </div>
#  <label class="check filter-option">
#  <div class="uitk-grid all-grid-fallback-alt">
#  <div class="uitk-col all-col-fill">
#  <input type="checkbox"/>
#  <span aria-hidden="true" class="inline-label">
#                                      Morning (5:00am - 11:59am)
#
#                  </span>
#  </div>
#  <div class="uitk-col all-col-shrink">
#  </div>
#  </div>
#  </label>
#  <label class="check filter-option">
#  <div class="uitk-grid all-grid-fallback-alt">
#  <div class="uitk-col all-col-fill">
#  <input type="checkbox"/>
#  <span aria-hidden="true" class="inline-label">
#                                      Afternoon (12:00pm - 5:59pm)
#
#                  </span>
#  </div>
#  <div class="uitk-col all-col-shrink">
#  </div>
#  </div>
#  </label>
#  <label class="check filter-option">
#  <div class="uitk-grid all-grid-fallback-alt">
#  <div class="uitk-col all-col-fill">
#  <input type="checkbox"/>
#  <span aria-hidden="true" class="inline-label">
#                                      Evening (6:00pm - 11:59pm)
#
#                  </span>
#  </div>
#  <div class="uitk-col all-col-shrink">
#  </div>
#  </div>
#  </label>
#  </div>
#  </fieldset>
#  <script>
#          (function () {
#              var isInbound = window.location.hash && window.location.hash.indexOf('#leg') > -1,
#                  departureFilterToShow = isInbound ? 'departure-time-filters-inbound' : 'departure-time-filters-outbound',
#                  arrivalFilterToShow = isInbound ? 'arrival-time-filters-inbound' : 'arrival-time-filters-outbound',
#                  departureFilter = document.getElementById(departureFilterToShow);
#                  arrivalFilter = document.getElementById(arrivalFilterToShow);
#
#              departureFilterContentToShow = isInbound ? 'departure-time-filters-inbound-fieldset' : 'departure-time-filters-outbound-fieldset',
#              arrivalFilterContentToShow = isInbound ? 'arrival-time-filters-inbound-fieldset' : 'arrival-time-filters-outbound-fieldset',
#              departureFilterContent = document.getElementById(departureFilterContentToShow);
#              arrivalFilterContent = document.getElementById(arrivalFilterContentToShow);
#
#              if (departureFilter) {
#                  departureFilter.className = departureFilter.className.replace('hide', '');
#              }
#
#              if (arrivalFilter) {
#                  arrivalFilter.className = arrivalFilter.className.replace('hide', '');
#              }
#
#              if (departureFilterContent) {
#                  departureFilterContent.className = departureFilterContent.className.replace('hide', '');
#              }
#
#              if (arrivalFilterContent) {
#                  arrivalFilterContent.className = arrivalFilterContent.className.replace('hide', '');
#              }
#          })();
#      </script>
#  </div>
#  </div>
#  <style>
#      .aColWidgetUnderAd{ margin: 10px 0px 10px 20px; }
#  </style>
#  <div class="aColWidgetUnderAd">
#  <div aria-label="Advertisement" class="ad " data-adheight="600" data-adwidth="160" id="L1" style="overflow:hidden;width:160px;max-height:600px;margin-left:auto;margin-right:auto;">
#  </div>
#  <script>
#    (function(window, undefined) {
#      window.expads = window.expads || {};
#      window.expads.configuration = window.expads.configuration || {};
#      window.expads.configuration.displayAdSlots = window.expads.configuration.displayAdSlots || [];
#
#      var slotConfig = {},
#          pagePath = undefined,
#          slotIdOverride = undefined;
#
#          slotConfig.id = "L1";
#
#
#      slotConfig.width = 160;
#      slotConfig.height = 600;
#
#      if (slotIdOverride !== undefined) {
#        slotConfig.slotIdOverride = slotIdOverride;
#      }
#      if (pagePath !== undefined) {
#        slotConfig.pagePath = pagePath;
#      }
#      slotConfig.collapseEmptyDiv = false;
#
#      window.expads.configuration.displayAdSlots.push(slotConfig);
#    })(window);
#  </script>
#  </div>
#  <div data-click-handler="omnitureClickHandler" data-omniture-rfrr="ACol.Intent" id="intentMediaAdPlacement"></div>
#  </div>
#  <button class="uitk-drawer-only uitk-drawer-hidden-close sort-filter-done-button" data-control="drawer-close" type="action">Close Drawer</button>
#  </div>
#  </aside>
#  <section class="uitk-col desktop-col-3-4 all-x-gutter-12" id="bCol" role="main">
#  <div class="bColumn">
#  <div class="hide" id="fallbackSearchMessage"></div>
#  <h3 class="hide visuallyhidden" data-test-id="info-about-results" id="info-about-results">Information about your search results</h3>
#  <div class="hide" id="mixed-cabin-class-message"></div> <div class="sort-filter-button-wrap">
#  <div class="sort-bar-column">
#  <button aria-expanded="false" class="btn-secondary btn-utility sort-filter-drawer-button uitk-drawer-trigger uitk-drawer-only" data-click-handler="omnitureClickHandler" data-control="drawer-trigger" data-omniture-rfrr="FLT.SR.SortFilter.Open" disabled="" type="button"><span class="btn-label"><svg aria-hidden="true" class="sort-filter-svg" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0z" fill="none"></path><path d="M3 17v2h6v-2H3zM3 5v2h10V5H3zm10 16v-2h8v-2h-8v-2h-2v6h2zM7 9v2H3v2h4v2h2V9H7zm14 4v-2H11v2h10zm-6-4h2V7h4V5h-4V3h-2v6z"></path></svg><span class="visuallyhidden">Sort and Filter, <span class="filter-count">0</span> filters applied</span><span aria-hidden="true" class="badge badge-notification sort-filter-badge hidden" data-test-id="sort-filter-badge">0</span><span aria-hidden="true">Sort &amp; Filter</span></span></button>
#  </div> </div>
#  <div class="hidden" id="flexible-search"></div>
#  <div id="unrestricted-message-container"></div>
#  <div id="xsell-container"></div>
#  <h2 class="visuallyhidden" data-test-id="listings-header" id="listings-header">Search results</h2>
#  <ul class="segmented-list results-list hide" id="crossSellOfferList">
#  </ul>
#  <div class="air-earn-limits">
#  </div>
#  <div class="hide box" id="ajax-error"></div>
#  <div id="legal-disclosure"></div>
#  <div id="flight-listing-container">
#  </div>
#  <ul class="segmented-list results-list price-sort light-opacity basic-economy-forced-tray" id="flightModuleList">
#  <li class="flight-module segment offer-listing " data-test-id="flight-cached-module-2019-04-01t06:40:00-04:00-coach-yyz-den-ua-1799-coach-den-hnl-ua-328_2019-04-30t14:39:00-10:00-coach-hnl-sfo-ua-650-coach-sfo-ord-ua-680-coach-ord-yyz-ua-476_">
#  <h3 class="visuallyhidden" data-test-id="result-header">Result 0 when sorted by price, C$564.55</h3>
#  <div class="grid-container standard-padding " data-test-id="listing-main">
#  <div class="uitk-grid all-grid-fallback-alt" data-offer-natural-key="2019-04-01t06:40:00-04:00-coach-yyz-den-ua-1799-coach-den-hnl-ua-328;2019-04-30t14:39:00-10:00-coach-hnl-sfo-ua-650-coach-sfo-ord-ua-680-coach-ord-yyz-ua-476; " data-test-id="listing-summary">
#  <div class="uitk-col all-col-fill custom-short-r-margin">
#  <div class="uitk-grid all-grid-fallback-alt smalltablet-col-1-1 mobile-col-1-1" data-test-id="listing-trip-info">
#  <div class="uitk-col all-col-fill">
#  <div class="uitk-grid all-grid-fallback-alt">
#  <div class="uitk-col tablet-col-1-3 desktop-col-1-3 custom-col-r-margin ">
#  <div class="primary-content no-wrap custom-primary-padding">
#  <span class="medium-bold">
#  <span data-test-id="departure-time">6:40am</span>
#          -
#          <span data-test-id="arrival-time">1:03pm</span>
#  </span>
#  </div>
#  <div class="secondary-content overflow-ellipsis inline-children">
#  <div class="icon-container">
#  <figure class="image aspect-ratio1-1" data-alt="United logo" data-aspect-ratio="1-1" data-class="tile-media" data-media-type="image" data-src="//images.trvl-media.com/media/content/expus/graphics/static_content/fusion/v0.1b/images/airlines/s/UA_sq.jpg"><img alt="United logo" class="tile-media" src="//images.trvl-media.com/media/content/expus/graphics/static_content/fusion/v0.1b/images/airlines/s/UA_sq.jpg"/></figure>
#  </div>
#  <div data-test-id="airline-name">
#              United
#      </div>
#  </div>
#  </div>
#  <div class="uitk-col tablet-col-1-2 desktop-col-1-2 all-col-fill">
#  <div class="fluid-content inline-children custom-primary-padding">
#  <span data-test-id="duration">
#              12h 23m
#      </span>
#  <span data-test-num-stops="1">
#      (1 stop)
#      </span>
#  <div class="amenity-icons"></div>
#  </div>
#  <div class="secondary-content no-wrap" data-test-id="flight-info">
#  <span class="visuallyhidden">Departure airport:</span>
#      YYZ -
#      <span>
#  <span aria-hidden="true">
#          1h 18m in DEN
#      </span>
#  <span class="visuallyhidden">
#          Layover 1h 18m in DEN
#      </span>
#  </span>
#  <span class="visuallyhidden">Arrival airport:</span>
#      -
#      HNL
#                      </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="uitk-col all-col-shrink">
#  <div class="uitk-grid all-grid-fallback-alt all-grid-align-end align-right all-grid-nowrap smalltablet-col-1-1">
#  <div class="uitk-col price-details-container all-col-fill" data-test-id="price-column">
#  <div class="secondary-content">
#  <div><span aria-hidden="true" class=" loader-secondary loader-light loader loader-animated loading" title="Loading..."></span></div>
#  <div>Finalizing prices...</div>
#  </div>
#  </div>
#  <div class="uitk-col standard-col-l-margin all-col-shrink display-larger-screens-only">
#  <button class="btn-secondary btn-action t-select-btn" data-click-handler="omnitureClickHandler" data-omniture-rfrr="FLT.SR.Select.Disabled" disabled="true" type="button"><span class="btn-label"><span aria-hidden="true">Select</span><span class="visuallyhidden">Select result 0 when sorted by price</span></span></button>
#  </div>
#  </div>
#  </div>
#  <a class="btn btn-primary btn-text flex-link" data-click-handler="omnitureClickHandler" data-omniture-rfrr="FLT.SR.Select.Disabled" data-prevent-default="true" href="#" onclick="goToUDPWithCachedOffer(this);"><span class="btn-label"><span class="visuallyhidden">Select result {0} when sorted by price</span></span></a>
#  </div>
#  </div>
#  </li>
#  <li class="flight-module segment offer-listing " data-test-id="flight-cached-module-2019-04-01t08:00:00-04:00-coach-yyz-lax-ua-8321-coach-lax-hnl-ua-1431_2019-04-30t14:39:00-10:00-coach-hnl-sfo-ua-650-coach-sfo-ord-ua-680-coach-ord-yyz-ua-476_">
#  <h3 class="visuallyhidden" data-test-id="result-header">Result 1 when sorted by price, C$564.55</h3>
#  <div class="grid-container standard-padding " data-test-id="listing-main">
#  <div class="uitk-grid all-grid-fallback-alt" data-offer-natural-key="2019-04-01t08:00:00-04:00-coach-yyz-lax-ua-8321-coach-lax-hnl-ua-1431;2019-04-30t14:39:00-10:00-coach-hnl-sfo-ua-650-coach-sfo-ord-ua-680-coach-ord-yyz-ua-476; " data-test-id="listing-summary">
#  <div class="uitk-col all-col-fill custom-short-r-margin">
#  <div class="uitk-grid all-grid-fallback-alt smalltablet-col-1-1 mobile-col-1-1" data-test-id="listing-trip-info">
#  <div class="uitk-col all-col-fill">
#  <div class="uitk-grid all-grid-fallback-alt">
#  <div class="uitk-col tablet-col-1-3 desktop-col-1-3 custom-col-r-margin ">
#  <div class="primary-content no-wrap custom-primary-padding">
#  <span class="medium-bold">
#  <span data-test-id="departure-time">8:00am</span>
#          -
#          <span data-test-id="arrival-time">4:37pm</span>
#  </span>
#  </div>
#  <div class="secondary-content overflow-ellipsis inline-children">
#  <div class="icon-container">
#  <figure class="image aspect-ratio1-1" data-alt="United logo" data-aspect-ratio="1-1" data-class="tile-media" data-media-type="image" data-src="//images.trvl-media.com/media/content/expus/graphics/static_content/fusion/v0.1b/images/airlines/s/UA_sq.jpg"><img alt="United logo" class="tile-media" src="//images.trvl-media.com/media/content/expus/graphics/static_content/fusion/v0.1b/images/airlines/s/UA_sq.jpg"/></figure>
#  </div>
#  <div data-test-id="airline-name">
#              United
#      </div>
#  </div>
#  </div>
#  <div class="uitk-col tablet-col-1-2 desktop-col-1-2 all-col-fill">
#  <div class="fluid-content inline-children custom-primary-padding">
#  <span data-test-id="duration">
#              14h 37m
#      </span>
#  <span data-test-num-stops="1">
#      (1 stop)
#      </span>
#  <div class="amenity-icons"></div>
#  </div>
#  <div class="secondary-content no-wrap" data-test-id="flight-info">
#  <span class="visuallyhidden">Departure airport:</span>
#      YYZ -
#      <span>
#  <span aria-hidden="true">
#          3h 32m in LAX
#      </span>
#  <span class="visuallyhidden">
#          Layover 3h 32m in LAX
#      </span>
#  </span>
#  <span class="visuallyhidden">Arrival airport:</span>
#      -
#      HNL
#                      </div>
#  <div class="secondary-content overflow-ellipsis" data-test-id="operated-by">
#          United 8321 operated by Air Canada
#                          </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="uitk-col all-col-shrink">
#  <div class="uitk-grid all-grid-fallback-alt all-grid-align-end align-right all-grid-nowrap smalltablet-col-1-1">
#  <div class="uitk-col price-details-container all-col-fill" data-test-id="price-column">
#  <div class="secondary-content">
#  <div><span aria-hidden="true" class=" loader-secondary loader-light loader loader-animated loading" title="Loading..."></span></div>
#  <div>Finalizing prices...</div>
#  </div>
#  </div>
#  <div class="uitk-col standard-col-l-margin all-col-shrink display-larger-screens-only">
#  <button class="btn-secondary btn-action t-select-btn" data-click-handler="omnitureClickHandler" data-omniture-rfrr="FLT.SR.Select.Disabled" disabled="true" type="button"><span class="btn-label"><span aria-hidden="true">Select</span><span class="visuallyhidden">Select result 1 when sorted by price</span></span></button>
#  </div>
#  </div>
#  </div>
#  <a class="btn btn-primary btn-text flex-link" data-click-handler="omnitureClickHandler" data-omniture-rfrr="FLT.SR.Select.Disabled" data-prevent-default="true" href="#" onclick="goToUDPWithCachedOffer(this);"><span class="btn-label"><span class="visuallyhidden">Select result {1} when sorted by price</span></span></a>
#  </div>
#  </div>
#  </li>
#  <li class="flight-module segment offer-listing " data-test-id="flight-cached-module-2019-04-01t06:30:00-04:00-coach-yyz-msp-dl-5457-coach-msp-hnl-dl-577_2019-04-30t20:41:00-10:00-coach-hnl-lax-dl-1212-coach-lax-slc-dl-2761-coach-slc-yyz-dl-2797_">
#  <h3 class="visuallyhidden" data-test-id="result-header">Result 2 when sorted by price, C$574.54</h3>
#  <div class="grid-container standard-padding " data-test-id="listing-main">
#  <div class="uitk-grid all-grid-fallback-alt" data-offer-natural-key="2019-04-01t06:30:00-04:00-coach-yyz-msp-dl-5457-coach-msp-hnl-dl-577;2019-04-30t20:41:00-10:00-coach-hnl-lax-dl-1212-coach-lax-slc-dl-2761-coach-slc-yyz-dl-2797; " data-test-id="listing-summary">
#  <div class="uitk-col all-col-fill custom-short-r-margin">
#  <div class="uitk-grid all-grid-fallback-alt smalltablet-col-1-1 mobile-col-1-1" data-test-id="listing-trip-info">
#  <div class="uitk-col all-col-fill">
#  <div class="uitk-grid all-grid-fallback-alt">
#  <div class="uitk-col tablet-col-1-3 desktop-col-1-3 custom-col-r-margin ">
#  <div class="primary-content no-wrap custom-primary-padding">
#  <span class="medium-bold">
#  <span data-test-id="departure-time">6:30am</span>
#          -
#          <span data-test-id="arrival-time">3:22pm</span>
#  </span>
#  </div>
#  <div class="secondary-content overflow-ellipsis inline-children">
#  <div class="icon-container">
#  <figure class="image aspect-ratio1-1" data-alt="Delta logo" data-aspect-ratio="1-1" data-class="tile-media" data-media-type="image" data-src="//images.trvl-media.com/media/content/expus/graphics/static_content/fusion/v0.1b/images/airlines/s/DL_sq.jpg"><img alt="Delta logo" class="tile-media" src="//images.trvl-media.com/media/content/expus/graphics/static_content/fusion/v0.1b/images/airlines/s/DL_sq.jpg"/></figure>
#  </div>
#  <div data-test-id="airline-name">
#              Delta
#      </div>
#  </div>
#  </div>
#  <div class="uitk-col tablet-col-1-2 desktop-col-1-2 all-col-fill">
#  <div class="fluid-content inline-children custom-primary-padding">
#  <span data-test-id="duration">
#              14h 52m
#      </span>
#  <span data-test-num-stops="1">
#      (1 stop)
#      </span>
#  <div class="amenity-icons"></div>
#  </div>
#  <div class="secondary-content no-wrap" data-test-id="flight-info">
#  <span class="visuallyhidden">Departure airport:</span>
#      YYZ -
#      <span>
#  <span aria-hidden="true">
#          3h 16m in MSP
#      </span>
#  <span class="visuallyhidden">
#          Layover 3h 16m in MSP
#      </span>
#  </span>
#  <span class="visuallyhidden">Arrival airport:</span>
#      -
#      HNL
#                      </div>
#  <div class="secondary-content overflow-ellipsis" data-test-id="operated-by">
#          Delta 5457 operated by Endeavor Air DBA Delta Connection
#                          </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="uitk-col all-col-shrink">
#  <div class="uitk-grid all-grid-fallback-alt all-grid-align-end align-right all-grid-nowrap smalltablet-col-1-1">
#  <div class="uitk-col price-details-container all-col-fill" data-test-id="price-column">
#  <div class="secondary-content">
#  <div><span aria-hidden="true" class=" loader-secondary loader-light loader loader-animated loading" title="Loading..."></span></div>
#  <div>Finalizing prices...</div>
#  </div>
#  </div>
#  <div class="uitk-col standard-col-l-margin all-col-shrink display-larger-screens-only">
#  <button class="btn-secondary btn-action t-select-btn" data-click-handler="omnitureClickHandler" data-omniture-rfrr="FLT.SR.Select.Disabled" disabled="true" type="button"><span class="btn-label"><span aria-hidden="true">Select</span><span class="visuallyhidden">Select result 2 when sorted by price</span></span></button>
#  </div>
#  </div>
#  </div>
#  <a class="btn btn-primary btn-text flex-link" data-click-handler="omnitureClickHandler" data-omniture-rfrr="FLT.SR.Select.Disabled" data-prevent-default="true" href="#" onclick="goToUDPWithCachedOffer(this);"><span class="btn-label"><span class="visuallyhidden">Select result {2} when sorted by price</span></span></a>
#  </div>
#  </div>
#  </li>
#  <li class="flight-module segment offer-listing " data-test-id="flight-cached-module-2019-04-01t06:40:00-04:00-coach-yyz-dfw-aa-1169-coach-dfw-koa-aa-229-coach-koa-hnl-aa-7901_2019-04-30t14:36:00-10:00-coach-hnl-lax-aa-284-coach-lax-clt-aa-1871-coach-clt-yyz-aa-5612_">
#  <h3 class="visuallyhidden" data-test-id="result-header">Result 3 when sorted by price, C$703.54</h3>
#  <div class="grid-container standard-padding " data-test-id="listing-main">
#  <div class="uitk-grid all-grid-fallback-alt" data-offer-natural-key="2019-04-01t06:40:00-04:00-coach-yyz-dfw-aa-1169-coach-dfw-koa-aa-229-coach-koa-hnl-aa-7901;2019-04-30t14:36:00-10:00-coach-hnl-lax-aa-284-coach-lax-clt-aa-1871-coach-clt-yyz-aa-5612; " data-test-id="listing-summary">
#  <div class="uitk-col all-col-fill custom-short-r-margin">
#  <div class="uitk-grid all-grid-fallback-alt smalltablet-col-1-1 mobile-col-1-1" data-test-id="listing-trip-info">
#  <div class="uitk-col all-col-fill">
#  <div class="uitk-grid all-grid-fallback-alt">
#  <div class="uitk-col tablet-col-1-3 desktop-col-1-3 custom-col-r-margin ">
#  <div class="primary-content no-wrap custom-primary-padding">
#  <span class="medium-bold">
#  <span data-test-id="departure-time">6:40am</span>
#          -
#          <span data-test-id="arrival-time">5:37pm</span>
#  </span>
#  </div>
#  <div class="secondary-content overflow-ellipsis inline-children">
#  <div class="icon-container">
#  <figure class="image aspect-ratio1-1" data-alt="American Airlines logo" data-aspect-ratio="1-1" data-class="tile-media" data-media-type="image" data-src="//images.trvl-media.com/media/content/expus/graphics/static_content/fusion/v0.1b/images/airlines/s/AA_sq.jpg"><img alt="American Airlines logo" class="tile-media" src="//images.trvl-media.com/media/content/expus/graphics/static_content/fusion/v0.1b/images/airlines/s/AA_sq.jpg"/></figure>
#  </div>
#  <div data-test-id="airline-name">
#              American Airlines
#      </div>
#  </div>
#  </div>
#  <div class="uitk-col tablet-col-1-2 desktop-col-1-2 all-col-fill">
#  <div class="fluid-content inline-children custom-primary-padding">
#  <span data-test-id="duration">
#              16h 57m
#      </span>
#  <span data-test-num-stops="2">
#      (2 stops)
#      </span>
#  <div class="amenity-icons"></div>
#  </div>
#  <div class="secondary-content no-wrap" data-test-id="flight-info">
#  <span class="visuallyhidden">Departure airport:</span>
#      YYZ -
#      <span>
#  <span class="layover-stops">DFW - KOA</span>
#  </span>
#  <span class="visuallyhidden">Arrival airport:</span>
#      -
#      HNL
#                      </div>
#  <div class="secondary-content overflow-ellipsis" data-test-id="operated-by">
#          American Airlines 7901 operated by Hawaiian Airlines
#                          </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="uitk-col all-col-shrink">
#  <div class="uitk-grid all-grid-fallback-alt all-grid-align-end align-right all-grid-nowrap smalltablet-col-1-1">
#  <div class="uitk-col price-details-container all-col-fill" data-test-id="price-column">
#  <div class="secondary-content">
#  <div><span aria-hidden="true" class=" loader-secondary loader-light loader loader-animated loading" title="Loading..."></span></div>
#  <div>Finalizing prices...</div>
#  </div>
#  </div>
#  <div class="uitk-col standard-col-l-margin all-col-shrink display-larger-screens-only">
#  <button class="btn-secondary btn-action t-select-btn" data-click-handler="omnitureClickHandler" data-omniture-rfrr="FLT.SR.Select.Disabled" disabled="true" type="button"><span class="btn-label"><span aria-hidden="true">Select</span><span class="visuallyhidden">Select result 3 when sorted by price</span></span></button>
#  </div>
#  </div>
#  </div>
#  <a class="btn btn-primary btn-text flex-link" data-click-handler="omnitureClickHandler" data-omniture-rfrr="FLT.SR.Select.Disabled" data-prevent-default="true" href="#" onclick="goToUDPWithCachedOffer(this);"><span class="btn-label"><span class="visuallyhidden">Select result {3} when sorted by price</span></span></a>
#  </div>
#  </div>
#  </li>
#  <li class="flight-module segment offer-listing " data-test-id="flight-cached-module-2019-04-01t06:40:00-04:00-coach-yyz-dfw-aa-1169-coach-dfw-koa-aa-229-coach-koa-hnl-aa-7861_2019-04-30t14:36:00-10:00-coach-hnl-lax-aa-284-coach-lax-clt-aa-1871-coach-clt-yyz-aa-5612_">
#  <h3 class="visuallyhidden" data-test-id="result-header">Result 4 when sorted by price, C$703.54</h3>
#  <div class="grid-container standard-padding " data-test-id="listing-main">
#  <div class="uitk-grid all-grid-fallback-alt" data-offer-natural-key="2019-04-01t06:40:00-04:00-coach-yyz-dfw-aa-1169-coach-dfw-koa-aa-229-coach-koa-hnl-aa-7861;2019-04-30t14:36:00-10:00-coach-hnl-lax-aa-284-coach-lax-clt-aa-1871-coach-clt-yyz-aa-5612; " data-test-id="listing-summary">
#  <div class="uitk-col all-col-fill custom-short-r-margin">
#  <div class="uitk-grid all-grid-fallback-alt smalltablet-col-1-1 mobile-col-1-1" data-test-id="listing-trip-info">
#  <div class="uitk-col all-col-fill">
#  <div class="uitk-grid all-grid-fallback-alt">
#  <div class="uitk-col tablet-col-1-3 desktop-col-1-3 custom-col-r-margin ">
#  <div class="primary-content no-wrap custom-primary-padding">
#  <span class="medium-bold">
#  <span data-test-id="departure-time">6:40am</span>
#          -
#          <span data-test-id="arrival-time">6:21pm</span>
#  </span>
#  </div>
#  <div class="secondary-content overflow-ellipsis inline-children">
#  <div class="icon-container">
#  <figure class="image aspect-ratio1-1" data-alt="American Airlines logo" data-aspect-ratio="1-1" data-class="tile-media" data-media-type="image" data-src="//images.trvl-media.com/media/content/expus/graphics/static_content/fusion/v0.1b/images/airlines/s/AA_sq.jpg"><img alt="American Airlines logo" class="tile-media" src="//images.trvl-media.com/media/content/expus/graphics/static_content/fusion/v0.1b/images/airlines/s/AA_sq.jpg"/></figure>
#  </div>
#  <div data-test-id="airline-name">
#              American Airlines
#      </div>
#  </div>
#  </div>
#  <div class="uitk-col tablet-col-1-2 desktop-col-1-2 all-col-fill">
#  <div class="fluid-content inline-children custom-primary-padding">
#  <span data-test-id="duration">
#              17h 41m
#      </span>
#  <span data-test-num-stops="2">
#      (2 stops)
#      </span>
#  <div class="amenity-icons"></div>
#  </div>
#  <div class="secondary-content no-wrap" data-test-id="flight-info">
#  <span class="visuallyhidden">Departure airport:</span>
#      YYZ -
#      <span>
#  <span class="layover-stops">DFW - KOA</span>
#  </span>
#  <span class="visuallyhidden">Arrival airport:</span>
#      -
#      HNL
#                      </div>
#  <div class="secondary-content overflow-ellipsis" data-test-id="operated-by">
#          American Airlines 7861 operated by Hawaiian Airlines
#                          </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="uitk-col all-col-shrink">
#  <div class="uitk-grid all-grid-fallback-alt all-grid-align-end align-right all-grid-nowrap smalltablet-col-1-1">
#  <div class="uitk-col price-details-container all-col-fill" data-test-id="price-column">
#  <div class="secondary-content">
#  <div><span aria-hidden="true" class=" loader-secondary loader-light loader loader-animated loading" title="Loading..."></span></div>
#  <div>Finalizing prices...</div>
#  </div>
#  </div>
#  <div class="uitk-col standard-col-l-margin all-col-shrink display-larger-screens-only">
#  <button class="btn-secondary btn-action t-select-btn" data-click-handler="omnitureClickHandler" data-omniture-rfrr="FLT.SR.Select.Disabled" disabled="true" type="button"><span class="btn-label"><span aria-hidden="true">Select</span><span class="visuallyhidden">Select result 4 when sorted by price</span></span></button>
#  </div>
#  </div>
#  </div>
#  <a class="btn btn-primary btn-text flex-link" data-click-handler="omnitureClickHandler" data-omniture-rfrr="FLT.SR.Select.Disabled" data-prevent-default="true" href="#" onclick="goToUDPWithCachedOffer(this);"><span class="btn-label"><span class="visuallyhidden">Select result {4} when sorted by price</span></span></a>
#  </div>
#  </div>
#  </li>
#  </ul>
#  <script>
#                                      window.serverSideOfferClicked = false;
#
#                                      if (dctk && dctk.ewePerformance) {
#                                          dctk.ewePerformance.mark('renderCachedOffers');
#                                      } else if (window.performance && typeof window.performance.mark === 'function') {
#                                          window.performance.mark('renderCachedOffers');
#                                      }
#
#                                      function createOmnitureRfrr(buttonData) {
#                                          if (!buttonData) {
#                                              return '';
#                                          }
#
#                                          var superlatives = buttonData.getNamedItem('data-superlatives').value || '',
#                                                  offerIndex = buttonData.getNamedItem('data-offer-index').value || '',
#                                                  openInSameTab = false,
#                                                  isOneWay = false,
#                                                  areExactMatchOffers = true,
#                                                  omnitureRfrr = 'FLT.SR.Select.Offer' + offerIndex + '.CachedPrice';
#
#                                          omnitureRfrr += areExactMatchOffers ?
#                                                  '.ExactMatch' :
#                                                  '.PartialMatch';
#
#                                          if (superlatives !== '') {
#                                              omnitureRfrr += '.' + superlatives;
#                                          }
#
#                                          if (openInSameTab && isOneWay) {
#                                              omnitureRfrr += areExactMatchOffers ?
#                                                      '%7CFLT.SR.Cache.ExactMatch' :
#                                                      '%7CFLT.SR.Cache.PartialMatch';
#                                          }
#
#                                          return omnitureRfrr;
#                                      }
#
#                                      function getInboundOffersForCachedOffer(target, event) {
#                                          var buttonData = target.attributes,
#                                                  buttons,
#                                                  omnitureRfrr = createOmnitureRfrr(buttonData),
#                                                  modal = document.createElement('div'),
#                                                  modalText = 'Finding return flights...',
#                                                  modalInnerHTML = '<div class="modal-inner"><div class="modal-body"><p>' + modalText + '</p></div></div>';
#
#                                          if (buttonData.getNamedItem('data-bargain-fare').value === 'true') {
#                                              goToUDPWithCachedOffer(target);
#                                          } else {
#                                              window.serverSideOfferClicked = true;
#                                              window.location.hash = '#leg/' + buttonData.getNamedItem('data-leg0-natural-key').value;
#
#                                              modal.setAttribute('class', 'modal-wrap uitk-tooltip-container theme-onpage-interstitial active on-page-interstitial-ab13327 on-page-interstitial-server-side-offer-clicked');
#                                              modal.innerHTML = modalInnerHTML;
#
#                                              document.getElementsByTagName('body')[0].appendChild(modal);
#                                              document.getElementById('bCol').classList.add('overlay');
#                                              document.querySelector('html').classList.add('active-modal');
#
#                                              buttons = document.querySelectorAll('.t-select-btn');
#                                              for (var i = 0, l = buttons.length; i < l; i++) {
#                                                  buttons[i].setAttribute('disabled', true);
#                                              }
#
#                                              logOmnitureFromServerSideOffers(omnitureRfrr);
#                                          }
#
#                                          if (event && typeof event.preventDefault === 'function') {
#                                              event.preventDefault();
#                                          }
#                                      }
#
#                                      function goToUDPWithCachedOffer(target) {
#                                          var buttonData = target.attributes,
#                                                  openInSameTab = false,
#                                                  omnitureRfrr = createOmnitureRfrr(buttonData),
#                                                  superlatives = buttonData.getNamedItem('data-superlatives').value || '',
#                                                  areExactMatchOffers = true,
#                                                  url;
#
#                                          if (undefined !== buttonData.getNamedItem('data-trip-id').value) {
#                                              if(buttonData.getNamedItem('data-has-fare').value || buttonData.getNamedItem('data-bargain-fare').value) {
#                                                  url = 'Flight-Details-PI?c=' + '1e38468f-7ef1-4a36-baff-63026eb1e73c' +
#                                                      '&tripId1=' + ' ' +
#                                                      '&offerId=' + encodeURIComponent(buttonData.getNamedItem('data-trip-id').value) +
#                                                      '&leg1=' + superlatives +
#                                                      '&leg2=' + superlatives +
#                                                      '&xsellchoice=normal&addHotelPackage=false&isSplitTicket=' + buttonData.getNamedItem('data-is-split-ticket').value +
#                                                      '&rfrr=' + omnitureRfrr +
#                                                      '&price=' + buttonData.getNamedItem('data-price').value +
#                                                      '&isPartialMatch=' + !areExactMatchOffers;
#                                              } else {
#                                                  url = 'Flight-Select?c=' + '1e38468f-7ef1-4a36-baff-63026eb1e73c' +
#                                                          '&rt=' + buttonData.getNamedItem('data-result-token').value +
#                                                          '&legs=' + buttonData.getNamedItem('data-leg-indexes').value +
#                                                          '&xsellchoice=normal&addHotelPackage=false&isSplitTicket=' + buttonData.getNamedItem('data-is-split-ticket').value;
#                                              }
#
#
#
#                                              window.open(url, '_blank').opener = null;
#                                          }
#                                      }
#
#                                      function logOmnitureFromServerSideOffers(omnitureRfrr) {
#                                          require('dctk/dctk', function (dctk) {
#                                              dctk.onReady(function () {
#                                                  dctk.trackAction(omnitureRfrr);
#                                              });
#                                          });
#                                      }
#                                  </script>
#  <script id="cachedOfferRenderTimeInMs" type="text/javascript">
#                                      require('dctk/dctk', function (dctk) {
#                                          dctk.logging.logTrxEvent('flightSearch', ['clEventName01=FLUX_ServerSide_CachedOfferRenderTime', 'clEventTime01=' + 14]);
#                                      });
#                                  </script>
#  <div class="footer-ad-container ad-above-adsense" id="footer-ad-container">
#  <section class="footer-ads-col">
#  <div class="ad-desktop" data-click-handler="omnitureClickHandler" data-omniture-rfrr="Responsive.Ad.Click">
#  <div aria-label="Advertisement" class="ad " data-adheight="90" data-adwidth="728" id="CM1" style="overflow:hidden;width:728px;max-height:90px;margin-left:auto;margin-right:auto;">
#  </div>
#  <script>
#    (function(window, undefined) {
#      window.expads = window.expads || {};
#      window.expads.configuration = window.expads.configuration || {};
#      window.expads.configuration.displayAdSlots = window.expads.configuration.displayAdSlots || [];
#
#      var slotConfig = {},
#          pagePath = undefined,
#          slotIdOverride = undefined;
#
#          slotConfig.id = "CM1";
#
#
#      slotConfig.width = 728;
#      slotConfig.height = 90;
#
#      if (slotIdOverride !== undefined) {
#        slotConfig.slotIdOverride = slotIdOverride;
#      }
#      if (pagePath !== undefined) {
#        slotConfig.pagePath = pagePath;
#      }
#      slotConfig.collapseEmptyDiv = false;
#
#      window.expads.configuration.displayAdSlots.push(slotConfig);
#    })(window);
#  </script>
#  </div>
#  <div class="ad-tablet" data-click-handler="omnitureClickHandler" data-omniture-rfrr="Responsive.Ad.Click">
#  <div aria-label="Advertisement" class="ad " data-adheight="60" data-adwidth="468" id="CM2" style="overflow:hidden;width:468px;max-height:60px;margin-left:auto;margin-right:auto;">
#  </div>
#  <script>
#    (function(window, undefined) {
#      window.expads = window.expads || {};
#      window.expads.configuration = window.expads.configuration || {};
#      window.expads.configuration.displayAdSlots = window.expads.configuration.displayAdSlots || [];
#
#      var slotConfig = {},
#          pagePath = undefined,
#          slotIdOverride = undefined;
#
#          slotConfig.id = "CM2";
#
#
#      slotConfig.width = 468;
#      slotConfig.height = 60;
#
#      if (slotIdOverride !== undefined) {
#        slotConfig.slotIdOverride = slotIdOverride;
#      }
#      if (pagePath !== undefined) {
#        slotConfig.pagePath = pagePath;
#      }
#      slotConfig.collapseEmptyDiv = false;
#
#      window.expads.configuration.displayAdSlots.push(slotConfig);
#    })(window);
#  </script>
#  </div>
#  <div class="ad-mobile" data-click-handler="omnitureClickHandler" data-omniture-rfrr="Responsive.Ad.Click">
#  <div aria-label="Advertisement" class="ad " data-adheight="250" data-adwidth="300" id="CM3" style="overflow:hidden;width:300px;max-height:250px;margin-left:auto;margin-right:auto;">
#  </div>
#  <script>
#    (function(window, undefined) {
#      window.expads = window.expads || {};
#      window.expads.configuration = window.expads.configuration || {};
#      window.expads.configuration.displayAdSlots = window.expads.configuration.displayAdSlots || [];
#
#      var slotConfig = {},
#          pagePath = undefined,
#          slotIdOverride = undefined;
#
#          slotConfig.id = "CM3";
#
#
#      slotConfig.width = 300;
#      slotConfig.height = 250;
#
#      if (slotIdOverride !== undefined) {
#        slotConfig.slotIdOverride = slotIdOverride;
#      }
#      if (pagePath !== undefined) {
#        slotConfig.pagePath = pagePath;
#      }
#      slotConfig.collapseEmptyDiv = false;
#
#      window.expads.configuration.displayAdSlots.push(slotConfig);
#    })(window);
#  </script>
#  </div>
#  </section>
#  </div>
#  <div class="row" data-abacus-id="3" data-click-handler="omnitureClickHandler" data-omniture-rfrr="Footer.Adsense" id="gtFooterContainer">
#  <div class="ad adsense_footer small_ad" id="small-adsense-footer" name="adsense" style="height:0px; overflow:hidden;">
#  <div class="adsense_footer_content" id="small-adsense-footer-content">
#  <h5 class="visuallyhidden">ADVERTISEMENT SPONSORED LISTINGS</h5>
#  <h2 aria-hidden="true" class="ad_header_gtfooter">SPONSORED LISTINGS</h2>
#  <div class="ad_gtfooter_container">
#  <div class="ad_inner_gtfooter" id="small-adsense-footer-content-section1-container" style="display: block; width: 100%; padding: 0 18px 0 18px;">
#  <div data-title="Advertisement" id="small-adsense-footer-content-section1" style="display: block; width: 100%;"></div>
#  </div>
#  <div class="ad_inner_gtfooter" id="small-adsense-footer-content-section2-container" style="display: block; width: 100%; padding: 0 18px 9px 18px;">
#  <div data-title="Advertisement" id="small-adsense-footer-content-section2" style="display: block; width: 100%;"></div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="ad adsense_footer medium_ad" id="medium-adsense-footer" name="adsense" style="height:0px; overflow:hidden;">
#  <div class="adsense_footer_content" id="medium-adsense-footer-content">
#  <h5 class="visuallyhidden">ADVERTISEMENT SPONSORED LISTINGS</h5>
#  <h2 aria-hidden="true" class="ad_header_gtfooter">SPONSORED LISTINGS</h2>
#  <div class="ad_gtfooter_container">
# ...
#                          }
#                      },
#                      afternoon: {
#                          label: "Afternoon ({startTime} - {endTime})",
#                          outbound: {
#                              pill: {
#                                  multiLeg: "Departure flight landing: Afternoon (12:00pm - 5:59pm)",
#                                  singleLeg: "Afternoon (12:00pm - 5:59pm)"
#                              }
#                          },
#                          inbound: {
#                              pill: "Return flight landing: Afternoon (12:00pm - 5:59pm)"
#                          }
#                      },
#                      evening: {
#                          label: "Evening ({startTime} - {endTime})",
#                          outbound: {
#                              pill: {
#                                  multiLeg:"Departure flight landing: Evening (6:00pm - 11:59pm)",
#                                  singleLeg: "Evening (6:00pm - 11:59pm)"
#                              }
#                          },
#                          inbound: {
#                              pill: "Return flight landing: Evening (6:00pm - 11:59pm)"
#                          }
#                      }
#                  },
#                  departure: {
#                      oneWayCategoryTitle: "Departure time",
#                      categoryTitle: "Departure time - {0}",
#                      earlyMorning: {
#                          label: "Early Morning ({startTime} - {endTime})",
#                          outbound: {
#                              pill: {
#                                  multiLeg: "Departure flight take-off: Early Morning (12:00am - 4:59am)",
#                                  singleLeg: "Early Morning (12:00am - 4:59am)"
#                              }
#                          },
#                          inbound: {
#                              pill: "Return flight take-off: Early Morning (12:00am - 4:59am)"
#                          }
#                      },
#                      morning: {
#                          label: "Morning ({startTime} - {endTime})",
#                          outbound: {
#                              pill: {
#                                  multiLeg: "Departure flight take-off: Morning (5:00am - 11:59am)",
#                                  singleLeg: "Morning (5:00am - 11:59am)",
#                              }
#                          },
#                          inbound: {
#                              pill: "Return flight take-off: Morning (5:00am - 11:59am)"
#                          }
#                      },
#                      afternoon: {
#                          label: "Afternoon ({startTime} - {endTime})",
#                          outbound: {
#                              pill: {
#                                  multiLeg: "Departure flight take-off: Afternoon (12:00pm - 5:59pm)",
#                                  singleLeg: "Afternoon (12:00pm - 5:59pm)"
#                              }
#                          },
#                          inbound: {
#                              pill: "Return flight take-off: Afternoon (12:00pm - 5:59pm)"
#                          }
#                      },
#                      evening: {
#                          label: "Evening ({startTime} - {endTime})",
#                          outbound: {
#                              pill: {
#                                  multiLeg: "Departure flight take-off: Evening (6:00pm - 11:59pm)",
#                                  singleLeg: "Evening (6:00pm - 11:59pm)"
#                              }
#                          },
#                          inbound: {
#                              pill: "Return flight take-off: Evening (6:00pm - 11:59pm)"
#                          }
#                      }
#                  },
#              },
#              timeOfDay: {
#                  earlymorning: "Early Morning",
#                  morning: "Morning",
#                  afternoon: "Afternoon",
#                  evening: "Evening"
#              }
#          },
#          sessionmodal: {
#              countdownModalTimer: "Please refresh your search for the latest prices.",
#              refreshSearch: "Refresh Search"
#          },
#          standardofferdetails: {
#              accessibility: {
#                  detailsCollapsed: "details collapsed",
#                  detailsExpanded: "details expanded",
#                  departureDetailsDisplayed: "Departure details displayed",
#                  returnDetailsDisplayed: "Return details displayed",
#                  tripIndexDetailsDisplayed: "Trip {{tripIndex}} details displayed"
#              }
#          },
#          globalWizard : {
#              accessibility: {
#                  searching: "Searching"
#              },
#              travelerCount: "{0} Traveller",
#              travelersCount: "{0} Travellers",
#              nearbyAirport: {
#                  selectedForDeparture: "{0} is now selected for departure",
#                  selectedForArrival: "{0} is now selected for arrival"
#              }
#          },
#          interstitial : {
#              messages: [
#                  "Getting flight information...",
#                  "Searching for the shortest flights...",
#                  "Finding the best fares...",
#                  "Finalizing prices..."
#              ],
#              accessibility: {
#                  searchingForFlights: "Searching for flights"
#              }
#          },
#          error: {
#              accessibility: {
#                  timeoutRetry: "Click the try again button to retry your search",
#              }
#          },
#          headers: {
#              departureResults: "Departure search results",
#              returnResults: "Return search results",
#              mDestResults : "Multi-destination Leg {0} search results"
#          },
#          operatedBy: {
#              operatedByListInitial: "{{airlineName}} {{flightNumber}}",
#              operatedByList: "{{operatedByList}}, {{flightNumberToAppend}}",
#              operatedByListEnd: "{{operatedByList}} and {{finalFlightNumber}}",
#              operatedBy: "{{operatedByListEnd}} operated by {{operatingAirline}}"
#          },
#          bagWeightDetails: {
#              bagPerKg: "{fee} per kg</td>",
#              bagPerLbs: "{fee} per lbs</td>",
#
#              noFeeTag: "No fee</td>",
#              noFeeTagKg: "No fee up to {weight} kg</td>",
#              noFeeTagLbs: "No fee up to {weight} lbs</td>",
#
#              feeTag: "{fee}</td>",
#              feeTagKg: "{fee} up to {weight} kg</td>",
#              feeTagLbs: "{fee} up to {weight} lbs</td>"
#          },
#  		bagDetailsExpandedView: {
#              baggageFeesDescGeneric : "Here's the most up-to-date information we have on baggage fees collected by each airline. Once you have selected your flight(s), a final view of your itinerary along with the applicable baggage fees will be available in the Important Flight Information section. Fees may vary based on when and how you pay, frequent flyer status, baggage size, weight and currency amongst other factors. Please note that some airlines may have restrictions on the size and weight of baggage that is guaranteed to be placed in the cabin.",
#  			learnMoreBaggagePolicy : "",
#  			mostRecentBaggageFeeInfo : ""
#  		},
#          wizardInterstitial: {
#              searchingForFlightsTo: "Searching for flights to {airportCode}...",
#              finalizingFaresAndPrices: "Finalizing fares and prices..."
#          },
#          cabinClasses: {
#              firstCabinClass: "First Class",
#              firstCabinClassWithoutClassWord: "First",
#              businessCabinClass: "Business",
#              economyCabinClass: "Economy",
#              premiumEconomyCabinClass: "Premium Economy"
#          }
#      };
#  });
#  </script>
#  <script id="cachedResultsJson" type="application/json">{"content":"{\"legs\":{\"571f9a95f4506fb67afbc3bf0f038df5\":{\"identity\":{\"naturalKey\":\"571f9a95f4506fb67afbc3bf0f038df5\",\"index\":8},\"fareBasisCode\":\"LA0SA0EL\",\"index\":8,\"naturalKey\":\"571f9a95f4506fb67afbc3bf0f038df5\",\"price\":{\"hasFare\":true,\"flightFareTypeCode\":\"P\",\"flightFareTypeValue\":1,\"priceIllegal\":false,\"offerPrice\":726.0,\"exactPrice\":725.54,\"formattedPrice\":\"C$725.54\",\"formattedPriceWithCreditCardFeesEstimate\":\"\",\"formattedTotalPrice\":\"C$725.54\",\"totalPriceAsDecimal\":725.54,\"totalPriceAsDecimalString\":\"725.54\",\"formattedRoundedPrice\":\"C$726\",\"formattedRoundedTotalPrice\":\"C$726\",\"currencyCode\":\"CAD\",\"feesMessage\":{\"isShowBestPriceGuarantee\":true,\"showBaggageFeeIncludedMsg\":false,\"showCheckedBagIncludedMsg\":false,\"showFirstCheckedBagIncludedMsg\":false,\"showLCCBaggageAllowanceMsg\":false,\"baggageAllowance\":\"\",\"showOBFeeMessageForLeg\":false,\"isShowFreeCancellation\":false,\"showBaggageFeeNotIncludedMsg\":false,\"showBaggageFeeOnPurchaseMsg\":false,\"showHandBaggageOnlyMsg\":false,\"airlineBasedBaggageAllowance\":0,\"specialFareMessage\":\"\",\"freeCancellationTimeLimit\":0,\"showOBFeeDetailLink\":false,\"nextGenContentWithLink\":false,\"matchDataAirProvider\":true,\"isFlightIneligibleForBPG\":false},\"localizedCurrencyCode\":\"CAD\",\"bestPriceDelta\":160.99,\"formattedBestPriceDelta\":\"C$160.99\",\"formattedRoundedBestPriceDelta\":\"C$161\",\"roundedBestPriceDelta\":161,\"earnGPSRewards\":null,\"hasFees\":false,\"pricedFlight\":false},\"carrierSummary\":{\"airlineImageFileName\":\"DL.gif\",\"airProviderId\":2,\"seatMapAvailable\":true,\"airlineCodes\":[\"DL\",\"DL\"],\"mixedCabinClass\":false,\"daysTravelled\":0,\"displayUrgencyMessage\":false,\"noOfTicketsLeft\":7,\"airlineName\":\"Delta\",\"nextDayArrival\":false,\"multiStop\":true},\"timeline\":[{\"type\":\"Segment\",\"segment\":true,\"layover\":false,\"carrier\":{\"flightNumber\":\"7091\",\"seatMapAvailable\":true,\"airlineName\":\"Delta\",\"airlineImageFileName\":\"DL.gif\",\"airlineCode\":\"DL\",\"cabinClass\":\"3\",\"bookingCode\":\"L\",\"operatedBy\":\"WestJet\",\"operatedByAirlineCode\":\"WS\",\"plane\":\"\",\"planeCode\":\"\",\"airlineImageFileNameWithoutExtension\":\"DL\",\"showCabinClass\":true},\"departureAirport\":{\"code\":\"YYZ\",\"name\":\"Toronto (YYZ)\",\"longName\":\"Toronto, ON (YYZ-Pearson Intl.)\",\"city\":\"Toronto\",\"localName\":\"Pearson Intl.\",\"airportCityState\":\"Toronto, ON\"},\"arrivalAirport\":{\"code\":\"LAX\",\"name\":\"Los Angeles (LAX)\",\"longName\":\"Los Angeles, CA, United States (LAX-Los Angeles Intl.)\",\"city\":\"Los Angeles\",\"localName\":\"Los Angeles Intl.\",\"airportCityState\":\"Los Angeles, CA, United States\"},\"distance\":{\"total\":2160,\"unit\":\"km\",\"formattedTotal\":\"2,160\"},\"departureTime\":{\"date\":\"01/04/2019\",\"dateLongStr\":\"Mon, 1 Apr\",\"time\":\"9:55am\",\"dateTime\":1554126900000,\"travelDate\":\"04/01/19\",\"isoStr\":\"2019-04-01T09:55:00.000-04:00\",\"hour\":null},\"arrivalTime\":{\"date\":\"01/04/2019\",\"dateLongStr\":\"Mon, 1 Apr\",\"time\":\"12:35pm\",\"dateTime\":1554147300000,\"travelDate\":\"04/01/19\",\"isoStr\":\"2019-04-01T12:35:00.000-07:00\",\"hour\":null},\"duration\":{\"hours\":5,\"minutes\":40,\"numOfDays\":0,\"departureTimeOfDay\":null,\"arrivalTimeOfDay\":null},\"brandedFareName\":\"\",\"meals\":[\"Food For Purchase\"]},{\"type\":\"Layover\",\"segment\":false,\"layover\":true,\"layoverNumber\":1,\"airport\":{\"code\":\"LAX\",\"name\":\"Los Angeles (LAX)\",\"longName\":\"Los Angeles, CA, United States (LAX-Los Angeles Intl.)\",\"city\":\"Los Angeles\",\"localName\":\"Los Angeles Intl.\",\"airportCityState\":\"Los Angeles, CA, United States\"},\"duration\":{\"hours\":2,\"minutes\":20,\"numOfDays\":0,\"departureTimeOfDay\":null,\"arrivalTimeOfDay\":null}},{\"type\":\"Segment\",\"segment\":true,\"layover\":false,\"carrier\":{\"flightNumber\":\"155 ...
#  <script id="singlePageModel" type="application/json">
#      {
#          "isOneWay": false,
#          "departureCity": "Toronto",
#          "arrivalCity": "Honolulu",
#          "departureISODate": "2019-04-01",
#          "arrivalISODate": "2019-04-30",
#          "departureDateStr": "Mon, 1 Apr",
#          "arrivalDateStr": "Tue, 30 Apr",
#          "departureAirportCode": "YYZ",
#          "arrivalAirportCode": "HNL",
#          "serverViewedTimeInMS": "1,547,795,563,785",
#          "clientViewedTimeInMS": "1,547,795,563,785",
#          "priceFormatString": "C$#,##0.00",
#          "decimalSeparator": ".",
#          "productKeyFromMetaPartner": "",
#          "emailTime": "",
#          "emailPrice": "",
#          "isPriceChanged": "",
#          "isUserRegistered": "false",
#          "searchUrl": "Flights-Search?trip=roundtrip&leg1=from:YYZ,to:HNL,departure:01/04/2019TANYT&leg2=from:HNL,to:YYZ,departure:30/04/2019TANYT,nopenalty:N,sortby:price&mode=search&rfrr=FLT.SR.History",
#          "currencyCode" : "CAD",
#          "isUsaDomestic" : false,
#          "endDateBrandedDeal" : "2019-04-30"
#      }
#  </script>
#  <script id="frame-page-performance-model" type="application/json">
#      {"tag":"","timeline":[{"name":"Init","value":0,"source":"ORIGINAL"},{"name":"GetSearchContext","value":103,"source":"ORIGINAL"},{"name":"InvokeSplitTicketing","value":0,"source":"ORIGINAL"},{"name":"ValidationResults","value":0,"source":"ORIGINAL"},{"name":"GetAirlines","value":0,"source":"ORIGINAL"},{"name":"GetSearchParameters","value":2,"source":"ORIGINAL"},{"name":"UpdatePartnerUserEligibility","value":0,"source":"ORIGINAL"},{"name":"GetFlightMessageModel","value":1,"source":"ORIGINAL"},{"name":"NearbyAirportsModel","value":21,"source":"ORIGINAL"},{"name":"FlightConfigurationModel","value":2,"source":"ORIGINAL"},{"name":"AddFlexibleShoppingModels","value":0,"source":"ORIGINAL"},{"name":"StoreSearchedFlights","value":1,"source":"ORIGINAL"},{"name":"PartnerPointsMessaging","value":0,"source":"ORIGINAL"},{"name":"GetSiteAnalyticsData","value":0,"source":"ORIGINAL"},{"name":"AddAirPriceChanged","value":0,"source":"ORIGINAL"},{"name":"GetExperimentModel","value":3,"source":"ORIGINAL"},{"name":"AddCachedResults","value":30,"source":"ORIGINAL"},{"name":"GetOmnitureDataAsJSON","value":1,"source":"ORIGINAL"}],"totalTime":167,"operations":{"FlightConfigurationModel":[{"name":"FlightConfigurationModel","value":2,"source":"ORIGINAL"}],"PartnerPointsMessaging":[{"name":"PartnerPointsMessaging","value":0,"source":"ORIGINAL"}],"GetExperimentModel":[{"name":"GetExperimentModel","value":3,"source":"ORIGINAL"}],"GetSearchContext":[{"name":"GetSearchContext","value":103,"source":"ORIGINAL"}],"GetSearchParameters":[{"name":"GetSearchParameters","value":2,"source":"ORIGINAL"}],"StoreSearchedFlights":[{"name":"StoreSearchedFlights","value":1,"source":"ORIGINAL"}],"GetAirlines":[{"name":"GetAirlines","value":0,"source":"ORIGINAL"}],"AddUDO":[{"name":"AddUDO","value":0,"source":"ORIGINAL"}],"AddAirPriceChanged":[{"name":"AddAirPriceChanged","value":0,"source":"ORIGINAL"}],"AdjustSummary":[{"name":"AdjustSummary","value":1,"source":"ORIGINAL"}],"NearbyAirportsModel":[{"name":"NearbyAirportsModel","value":21,"source":"ORIGINAL"}],"GetSiteAnalyticsData":[{"name":"GetSiteAnalyticsData","value":0,"source":"ORIGINAL"}],"GetOmnitureDataAsJSON":[{"name":"GetOmnitureDataAsJSON","value":1,"source":"ORIGINAL"}],"AddCachedResults":[{"name":"AddCachedResults","value":30,"source":"ORIGINAL"}],"Init":[{"name":"Init","value":0,"source":"ORIGINAL"}],"ValidationResults":[{"name":"ValidationResults","value":0,"source":"ORIGINAL"}],"InvokeSplitTicketing":[{"name":"InvokeSplitTicketing","value":0,"source":"ORIGINAL"}],"GetFlightMessageModel":[{"name":"GetFlightMessageModel","value":1,"source":"ORIGINAL"}],"UpdatePartnerUserEligibility":[{"name":"UpdatePartnerUserEligibility","value":0,"source":"ORIGINAL"}],"AddFlexibleShoppingModels":[{"name":"AddFlexibleShoppingModels","value":0,"source":"ORIGINAL"}]}}
#  </script>
#  <div id="forceChoiceMessageContainer" style="display:none">
#      Save up to $750* when you book your Flight and Hotel together.
#  </div> </div>
#  <span aria-hidden="true" class="uitk-overlay theme-default uitk-drawer-only hsr-filter-drawer-overlay"></span>
#  </div>]

# %%
item_price = []
stops = []
airline = []
