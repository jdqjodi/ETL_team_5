# %%
# merging csvs
import pandas as pd
import os
import csv
from pprint import pprint
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('csvs/rental_rooms')

# %%
df.head()
# Out:
#    Unnamed: 0                                        Rental Room Rental Price
# 0           0  Hawaiian Monarch -Studio with Canal View/Parti...          $85
# 1           1  Fresh Renovated Inn on the Park Studio near Be...          $75
# 2           2                 1009 KING BED Modern/Waikiki Beach          $90
# 3           3  Fully Renovated Condo by Ocean with Full Kitch...          $85
# 4           4  Spacious 1BR with 180-Degree Ocean Views! Prim...         $120

# %%
df['Average Price']  = 108.5

# %%
df
# Out:
#     Unnamed: 0                                        Rental Room  \
# 0            0  Hawaiian Monarch -Studio with Canal View/Parti...
# 1            1  Fresh Renovated Inn on the Park Studio near Be...
# 2            2                 1009 KING BED Modern/Waikiki Beach
# 3            3  Fully Renovated Condo by Ocean with Full Kitch...
# 4            4  Spacious 1BR with 180-Degree Ocean Views! Prim...
# 5            5        ((( Ocean Views! ))) Newly Upgraded Studio!
# 6            6  Waikiki Grand - Diamond Head & Ocean Views, Ki...
# 7            7  Fairway Villa 804 / Studio - Free Wifi, TV & P...
# 8            8  Grand Opening Discount - Renovated Studio - Aw...
# 9            9  Easy Access to Amazing Beaches in this Beautif...
# 10          10            Brand New Waikiki Diamond Head Favorite
# 11          11  Wyndham Royal Garden Waikiki - Free WIFI In Ro...
# 12          12  New Listing! Modern Condo on the 29th Floor in...
# ...

# %%
df['Rental Price'] = df['Rental Price'].replace({'\$': ''}, regex=True)

# %%
df
# Out:
#     Unnamed: 0                                        Rental Room  \
# 0            0  Hawaiian Monarch -Studio with Canal View/Parti...
# 1            1  Fresh Renovated Inn on the Park Studio near Be...
# 2            2                 1009 KING BED Modern/Waikiki Beach
# 3            3  Fully Renovated Condo by Ocean with Full Kitch...
# 4            4  Spacious 1BR with 180-Degree Ocean Views! Prim...
# 5            5        ((( Ocean Views! ))) Newly Upgraded Studio!
# 6            6  Waikiki Grand - Diamond Head & Ocean Views, Ki...
# 7            7  Fairway Villa 804 / Studio - Free Wifi, TV & P...
# 8            8  Grand Opening Discount - Renovated Studio - Aw...
# 9            9  Easy Access to Amazing Beaches in this Beautif...
# 10          10            Brand New Waikiki Diamond Head Favorite
# 11          11  Wyndham Royal Garden Waikiki - Free WIFI In Ro...
# 12          12  New Listing! Modern Condo on the 29th Floor in...
# ...
